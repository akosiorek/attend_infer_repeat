# %%
import numpy as np

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
% matplotlib inline

from data import load_data
# Out:
# /Users/adam/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1357: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
data = load_data('mnist_train.pickle')

# %%
imgs = data['imgs']

# %%
fig, axes = plt.subplots(8, 8, figsize=(16, 16))
idx = np.random.choice(len(imgs), 64)
for i, ax in enumerate(axes.flatten()):
    ax.imshow(imgs[idx[i]], cmap='gray')#, vmin=0., vmax=1.)
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)

# %%
fig, ax = plt.subplots(1, 3, figsize=(9, 3))
ax[0].imshow(imgs.mean(0), cmap='gray')
ax[1].imshow(old_imgs.mean(0), cmap='gray')
ax[2].imshow((5*imgs.mean(0) + old_imgs.mean(0)), cmap='gray')

# %%
print np.random.choice(len(imgs), 64)
# Out:
# [134 423 262 454 233 494 152  66 360 390 442   7 158  75  41 483 257 251
#  404 348 320 388  86 136 318 387 177 171  75 483 344 362 200 451 193 143
#  220 145  53 340 247  12 239 340 313  95 403  16 409  81 318  93  18  80
#  378 469 417 458 259 241 194 164 398  40]
