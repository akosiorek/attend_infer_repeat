# %%
from os import path as osp
import numpy as np
import tensorflow as tf
import sonnet as snt
from attrdict import AttrDict

from evaluation import make_fig, make_logger

from data import load_data, tensors_from_data
from mnist_model import SeqAIRonMNIST

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
% matplotlib inline

# %%
learning_rate = 1e-4
n_steps = 3

results_dir = '../results/seq_grad_inspect'
run_name = 'no_baseline'

logdir = osp.join(results_dir, run_name)
checkpoint_name = osp.join(logdir, 'model.ckpt')
axes = {'imgs': 1, 'labels': 0, 'nums': 1, 'coords': 1}

# %%
n_timesteps = 1
batch_size = 64

num_steps_prior = AttrDict(
    anneal='exp',
    init=1.,
    final=1e-5,
    steps_div=1e4,
    steps=1e5,
    hold_init=1e3,
    analytic=False
)


appearance_prior = AttrDict(loc=0., scale=1.)
where_scale_prior = AttrDict(loc=0., scale=1.)
where_shift_prior = AttrDict(loc=0., scale=1.)

num_steps_prior = None
appearance_prior = None
where_scale_prior = None
where_shift_prior = None

use_reinforce = True
step_bias = .75
transform_var_bias = .5
output_multiplier = .5

l2_weight = 0. #1e-5

supervised_nums = False

# %%
# valid_data = load_data('small_seq_mnist_validation.pickle')
# train_data = load_data('small_seq_mnist_train.pickle')

# %%
valid_data = load_data('mnist_validation.pickle')
train_data = load_data('mnist_train.pickle')

# del axes['coords']
def fix(d):
    d.imgs = d.imgs[np.newaxis]
    d.nums = d.nums.T
    for k in d:
        print k, d[k].shape
    return d

valid_data, train_data = [fix(d) for d in (valid_data, train_data)]
# Out:
# imgs (1, 10000, 50, 50)
# labels (10000, 2)
# nums (1, 10000, 3)
# imgs (1, 60000, 50, 50)
# labels (60000, 2)
# nums (1, 60000, 3)

# %%
tf.reset_default_graph()
train_tensors = tensors_from_data(train_data, batch_size, axes, shuffle=True)
valid_tensors = tensors_from_data(valid_data, batch_size, axes, shuffle=False)
x, valid_x = train_tensors['imgs'], valid_tensors['imgs']
y, test_y = train_tensors['nums'], valid_tensors['nums']
    
n_hiddens = 32 * 8
n_layers = 2
n_hiddens = [n_hiddens] * n_layers
    
n_timesteps = tf.Variable(n_timesteps, trainable=False, dtype=tf.int32, name='n_timesteps')
seq_x = x[:n_timesteps]
seq_y = y[:n_timesteps]
air = SeqAIRonMNIST(seq_x,
                max_steps=n_steps,
                inpt_encoder_hidden=n_hiddens,
                glimpse_encoder_hidden=n_hiddens,
                glimpse_decoder_hidden=n_hiddens,
                transform_estimator_hidden=n_hiddens,
                steps_pred_hidden=[128, 64],
                baseline_hidden=[256, 128],
                transform_var_bias=transform_var_bias,
                step_bias=step_bias,
                output_multiplier=output_multiplier
)

# %%
train_step, global_step = air.train_step(learning_rate, l2_weight, appearance_prior, where_scale_prior,
                            where_shift_prior, num_steps_prior, use_reinforce=use_reinforce,
                            decay_rate=None, nums=seq_y, supervised_nums=supervised_nums)
# Out:
# reinf (?, 64) (?, 64, 1)
# model 34
# lstm/w_gates:0 [512, 1024]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear_2/b:0 [8]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear_2/w:0 [64, 1]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear_2/w:0 [256, 8]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear_2/b:0 [1]
# lstm/b_gates:0 [1024]
# SeqAIRonMNIST/SeqAIRCell/Encoder/MLP/linear_1/w:0 [256, 256]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear/w:0 [50, 256]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear/b:0 [256]
# SeqAIRonMNIST/lstm_initial_state_0/w:0 [1, 256]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear/w:0 [256, 256]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear/b:0 [256]
# SeqAIRonMNIST/SeqAIRCell/Encoder/MLP/linear/w:0 [2500, 256]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear_2/w:0 [256, 400]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear_1/b:0 [256]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear/b:0 [128]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear_1/w:0 [256, 256]
# SeqAIRonMNIST/SeqAIRCell/Encoder/MLP/linear_1/b:0 [256]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear_1/w:0 [128, 64]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear/w:0 [256, 128]
# SeqAIRonMNIST/what_init:0 [1, 50]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear_1/w:0 [256, 256]
# SeqAIRonMNIST/SeqAIRCell/StochasticTransformParam/MLP/linear_1/b:0 [256]
# SeqAIRonMNIST/lstm_initial_state_1/w:0 [1, 256]
# SeqAIRonMNIST/SeqAIRCell/ParametrisedGaussian/linear/b:0 [100]
# SeqAIRonMNIST/SeqAIRCell/Encoder_1/MLP/linear/w:0 [400, 256]
# SeqAIRonMNIST/SeqAIRCell/Encoder_1/MLP/linear_1/w:0 [256, 256]
# SeqAIRonMNIST/SeqAIRCell/Decoder/MLP/linear_2/b:0 [400]
# SeqAIRonMNIST/SeqAIRCell/ParametrisedGaussian/linear/w:0 [256, 100]
# SeqAIRonMNIST/SeqAIRCell/StepsPredictor/MLP/linear_1/b:0 [64]
# SeqAIRonMNIST/SeqAIRCell/Encoder_1/MLP/linear_1/b:0 [256]
# SeqAIRonMNIST/where_init:0 [1, 4]
# SeqAIRonMNIST/SeqAIRCell/Encoder_1/MLP/linear/b:0 [256]
# SeqAIRonMNIST/SeqAIRCell/Encoder/MLP/linear/b:0 [256]
# total parameters: 1782579
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Gradient for variable SeqAIRonMNIST/what_init is None
# Gradient for variable SeqAIRonMNIST/where_init is None

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
    
sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())

# %%
step_prob = air.num_steps_distrib.prob()
mean_prob = tf.reduce_mean(step_prob, (0, 1))
step_entropy = step_prob * tf.log(step_prob)
step_entropy = -tf.reduce_sum(step_entropy)

# %%
def compute_grad(y, x):
    g = tf.reduce_mean(tf.gradients(y, x)[0], (0, 1))
    norm = 1.#tf.sqrt(tf.reduce_sum(tf.square(g), -1, keep_dims=True))
    return g / norm

total_grad = compute_grad(air.opt_loss, step_prob)

grads = [total_grad]
names = ['total']

if air.use_prior:
    kl_grad = compute_grad(air.prior_loss.value, step_prob)
    grads.append(kl_grad)
    names.append('kl')
    
if use_reinforce:
    reinforce_grad = compute_grad(air.reinforce_loss, step_prob)
    grads.append(reinforce_grad)
    names.append('reinforce')
    
grads.append(mean_prob)
names.append('prob')


for g, name in zip(grads, names):
    step_grads = tf.unstack(g, axis=-1)
    for i, step_grad in enumerate(step_grads):
        tf.summary.scalar('prob_grad/{}_{}'.format(name, i), step_grad)

# %%
print grads
print names
# Out:
# [<tf.Tensor 'div:0' shape=(4,) dtype=float32>, <tf.Tensor 'div_1:0' shape=(4,) dtype=float32>, <tf.Tensor 'Mean_1:0' shape=(4,) dtype=float32>]
# ['total', 'reinforce', 'prob']

# %%
# a, d = sess.run([grads, mean_prob])
# for i in a:
#     print i
# print d

# %%
all_summaries = tf.summary.merge_all()
summary_writer = tf.summary.FileWriter(logdir, sess.graph)
saver = tf.train.Saver()

# %%
n_train_samples = train_data['imgs'].shape[axes['imgs']]
n_valid_samples = valid_data['imgs'].shape[axes['imgs']]
n_train_samples, n_valid_samples = [i//100 for i in (n_train_samples, n_valid_samples)] 
log = make_logger(air, sess, summary_writer, train_tensors, n_train_samples, valid_tensors, n_valid_samples)

# %%
n_train_samples, n_valid_samples
# Out:
# (600, 100)

# %%
# log(0)

# %%
# tensors = {
#     'loss': air.loss.value,
#     'imp_weight': .5*tf.reduce_mean((air.reinforce_imp_weight)**2),
#     'baseline_loss': air.baseline_loss,
#     'baseline': tf.reduce_mean(air.baseline)
# }

# %%
# output = sess.run(tensors)
# for o, v in output.iteritems():
#     print '{}: {}'.format(o, v)

# %%
* template and coord storing in data.create_mnist
* load_data returns an AttrDict
*

# %%
train_itr = sess.run(global_step)
print 'Starting training at iter = {}'.format(train_itr)

if train_itr == 0:
#     if air.use_reinforce:
#         sess.run(air._baseline_train_step)
    log(0)
    
while train_itr < 1e6:
        
    train_itr, _ = sess.run([global_step, train_step])
    
#     if train_itr % 100 == 0:
#     if (train_itr % 1000) < 100:
    if train_itr % 50 == 0:
        summaries = sess.run(all_summaries)
        summary_writer.add_summary(summaries, train_itr)
        
    if train_itr % 100 == 0:
        log(train_itr)
        
    if train_itr % 5000 == 0:
        saver.save(sess, checkpoint_name, global_step=train_itr)
#         make_fig(air, sess, logdir, train_itr)
# Out:
# Starting training at iter = 0
# Step 0, Data train loss = -118.6387, imp_weight = -118.6387, opt_loss = 40.1163, reinforce_loss = 158.7550, rec_loss = -118.6387, num_step = 1.3524, num_step_acc = 0.2222, eval time = 0.2532s
# Step 0, Data test loss = -29.1283, imp_weight = -29.1283, opt_loss = 9.4869, reinforce_loss = 38.6153, rec_loss = -29.1283, num_step = 1.4062, num_step_acc = 0.1719, eval time = 0.09908s
#
# Step 100, Data train loss = -199.0291, imp_weight = -199.0291, opt_loss = 66.0636, reinforce_loss = 265.0926, rec_loss = -199.0291, num_step = 1.2274, num_step_acc = 0.2153, eval time = 0.1685s
# Step 100, Data test loss = -150.9201, imp_weight = -150.9201, opt_loss = 49.1561, reinforce_loss = 200.0762, rec_loss = -150.9201, num_step = 1.3281, num_step_acc = 0.1875, eval time = 0.01688s
#
# Step 200, Data train loss = -263.1973, imp_weight = -263.1973, opt_loss = 68.8205, reinforce_loss = 332.0178, rec_loss = -263.1973, num_step = 1.2378, num_step_acc = 0.2049, eval time = 0.1832s
# Step 200, Data test loss = -163.1733, imp_weight = -163.1733, opt_loss = 26.4609, reinforce_loss = 189.6342, rec_loss = -163.1733, num_step = 1.0469, num_step_acc = 0.1562, eval time = 0.02532s
#
# Step 300, Data train loss = -268.5041, imp_weight = -268.5041, opt_loss = 62.2945, reinforce_loss = 330.7987, rec_loss = -268.5041, num_step = 0.9149, num_step_acc = 0.3212, eval time = 0.1857s
# Step 300, Data test loss = -189.3039, imp_weight = -189.3039, opt_loss = 36.2709, reinforce_loss = 225.5748, rec_loss = -189.3039, num_step = 0.9219, num_step_acc = 0.2188, eval time = 0.0175s
#
# Step 400, Data train loss = -268.8669, imp_weight = -268.8669, opt_loss = 72.7138, reinforce_loss = 341.5807, rec_loss = -268.8669, num_step = 1.0938, num_step_acc = 0.2309, eval time = 0.1791s
# Step 400, Data test loss = -202.9915, imp_weight = -202.9915, opt_loss = 70.7857, reinforce_loss = 273.7772, rec_loss = -202.9915, num_step = 1.2344, num_step_acc = 0.2188, eval time = 0.02017s
#
# Step 500, Data train loss = -326.5826, imp_weight = -326.5826, opt_loss = 84.1518, reinforce_loss = 410.7344, rec_loss = -326.5826, num_step = 1.0399, num_step_acc = 0.2882, eval time = 0.2368s
# Step 500, Data test loss = -266.5530, imp_weight = -266.5530, opt_loss = 79.1959, reinforce_loss = 345.7488, rec_loss = -266.5530, num_step = 1.2031, num_step_acc = 0.2188, eval time = 0.02749s
#
# Step 600, Data train loss = -374.7696, imp_weight = -374.7696, opt_loss = 96.3675, reinforce_loss = 471.1371, rec_loss = -374.7696, num_step = 1.0764, num_step_acc = 0.2691, eval time = 0.1997s
# Step 600, Data test loss = -267.5665, imp_weight = -267.5665, opt_loss = 68.9913, reinforce_loss = 336.5577, rec_loss = -267.5665, num_step = 1.0781, num_step_acc = 0.2188, eval time = 0.02128s
#
# Step 700, Data train loss = -327.8587, imp_weight = -327.8587, opt_loss = 72.9852, reinforce_loss = 400.8439, rec_loss = -327.8587, num_step = 0.9826, num_step_acc = 0.2465, eval time = 0.1939s
# Step 700, Data test loss = -296.6679, imp_weight = -296.6679, opt_loss = 100.2411, reinforce_loss = 396.9090, rec_loss = -296.6679, num_step = 1.0938, num_step_acc = 0.3125, eval time = 0.02093s
#
# Step 800, Data train loss = -348.2018, imp_weight = -348.2018, opt_loss = 87.5071, reinforce_loss = 435.7089, rec_loss = -348.2018, num_step = 1.1233, num_step_acc = 0.2535, eval time = 0.2219s
# Step 800, Data test loss = -291.7641, imp_weight = -291.7641, opt_loss = 83.0289, reinforce_loss = 374.7930, rec_loss = -291.7641, num_step = 0.9844, num_step_acc = 0.2812, eval time = 0.02469s
#
# Step 900, Data train loss = -343.7700, imp_weight = -343.7700, opt_loss = 71.9026, reinforce_loss = 415.6725, rec_loss = -343.7700, num_step = 1.1076, num_step_acc = 0.2708, eval time = 0.2254s
# Step 900, Data test loss = -314.8820, imp_weight = -314.8820, opt_loss = 70.1860, reinforce_loss = 385.0680, rec_loss = -314.8820, num_step = 1.0938, num_step_acc = 0.2500, eval time = 0.02461s
#
# Step 1000, Data train loss = -402.7753, imp_weight = -402.7753, opt_loss = 104.4238, reinforce_loss = 507.1991, rec_loss = -402.7753, num_step = 1.2639, num_step_acc = 0.2969, eval time = 0.1912s
# Step 1000, Data test loss = -343.4952, imp_weight = -343.4952, opt_loss = 106.7599, reinforce_loss = 450.2551, rec_loss = -343.4952, num_step = 1.3594, num_step_acc = 0.2188, eval time = 0.02173s
#
# Step 1100, Data train loss = -388.7345, imp_weight = -388.7345, opt_loss = 82.5175, reinforce_loss = 471.2519, rec_loss = -388.7345, num_step = 0.9965, num_step_acc = 0.2951, eval time = 0.2054s
# Step 1100, Data test loss = -293.0391, imp_weight = -293.0391, opt_loss = 43.9256, reinforce_loss = 336.9647, rec_loss = -293.0391, num_step = 0.9062, num_step_acc = 0.2656, eval time = 0.02228s
#
# Step 1200, Data train loss = -395.2000, imp_weight = -395.2000, opt_loss = 83.9404, reinforce_loss = 479.1405, rec_loss = -395.2000, num_step = 1.0139, num_step_acc = 0.2795, eval time = 0.2078s
# Step 1200, Data test loss = -315.3880, imp_weight = -315.3880, opt_loss = 88.3967, reinforce_loss = 403.7847, rec_loss = -315.3880, num_step = 1.0938, num_step_acc = 0.2500, eval time = 0.02094s
#
# Step 1300, Data train loss = -399.5376, imp_weight = -399.5376, opt_loss = 104.2446, reinforce_loss = 503.7823, rec_loss = -399.5376, num_step = 1.0833, num_step_acc = 0.2986, eval time = 0.193s
# Step 1300, Data test loss = -302.4121, imp_weight = -302.4121, opt_loss = 60.2089, reinforce_loss = 362.6210, rec_loss = -302.4121, num_step = 0.8594, num_step_acc = 0.2500, eval time = 0.01999s
#
# Step 1400, Data train loss = -360.0579, imp_weight = -360.0579, opt_loss = 75.1113, reinforce_loss = 435.1692, rec_loss = -360.0579, num_step = 0.9549, num_step_acc = 0.2934, eval time = 0.2109s
# Step 1400, Data test loss = -307.7798, imp_weight = -307.7798, opt_loss = 50.7978, reinforce_loss = 358.5775, rec_loss = -307.7798, num_step = 0.9219, num_step_acc = 0.2031, eval time = 0.02141s
#
# Step 1500, Data train loss = -435.1761, imp_weight = -435.1761, opt_loss = 118.6109, reinforce_loss = 553.7870, rec_loss = -435.1761, num_step = 1.2153, num_step_acc = 0.2917, eval time = 0.1975s
# Step 1500, Data test loss = -380.4075, imp_weight = -380.4075, opt_loss = 93.3188, reinforce_loss = 473.7263, rec_loss = -380.4075, num_step = 1.5469, num_step_acc = 0.1719, eval time = 0.02107s
#
# Step 1600, Data train loss = -479.1626, imp_weight = -479.1626, opt_loss = 115.3388, reinforce_loss = 594.5014, rec_loss = -479.1626, num_step = 1.4792, num_step_acc = 0.2951, eval time = 0.2114s
# Step 1600, Data test loss = -427.7907, imp_weight = -427.7907, opt_loss = 109.2709, reinforce_loss = 537.0616, rec_loss = -427.7907, num_step = 1.5000, num_step_acc = 0.2656, eval time = 0.02377s
#
# Step 1700, Data train loss = -464.4730, imp_weight = -464.4730, opt_loss = 140.7501, reinforce_loss = 605.2230, rec_loss = -464.4730, num_step = 1.7309, num_step_acc = 0.1788, eval time = 0.1976s
# Step 1700, Data test loss = -394.3186, imp_weight = -394.3186, opt_loss = 122.3436, reinforce_loss = 516.6622, rec_loss = -394.3186, num_step = 1.5625, num_step_acc = 0.2031, eval time = 0.02128s
#
# Step 1800, Data train loss = -462.6633, imp_weight = -462.6633, opt_loss = 152.2960, reinforce_loss = 614.9593, rec_loss = -462.6633, num_step = 1.6111, num_step_acc = 0.1997, eval time = 0.1937s
# Step 1800, Data test loss = -466.0257, imp_weight = -466.0257, opt_loss = 145.9919, reinforce_loss = 612.0176, rec_loss = -466.0257, num_step = 1.7031, num_step_acc = 0.2656, eval time = 0.02042s
#
# Step 1900, Data train loss = -497.6770, imp_weight = -497.6770, opt_loss = 151.6858, reinforce_loss = 649.3628, rec_loss = -497.6770, num_step = 1.7153, num_step_acc = 0.1927, eval time = 0.1836s
# Step 1900, Data test loss = -443.6578, imp_weight = -443.6578, opt_loss = 140.7401, reinforce_loss = 584.3979, rec_loss = -443.6578, num_step = 1.7812, num_step_acc = 0.2344, eval time = 0.01961s
#
# Step 2000, Data train loss = -480.3316, imp_weight = -480.3316, opt_loss = 151.7335, reinforce_loss = 632.0650, rec_loss = -480.3316, num_step = 1.7031, num_step_acc = 0.1962, eval time = 0.2066s
# Step 2000, Data test loss = -395.4669, imp_weight = -395.4669, opt_loss = 133.8643, reinforce_loss = 529.3312, rec_loss = -395.4669, num_step = 1.3906, num_step_acc = 0.1406, eval time = 0.02335s
# Step 2100, Data train loss = -507.3460, imp_weight = -507.3460, opt_loss = 162.0468, reinforce_loss = 669.3929, rec_loss = -507.3460, num_step = 1.7378, num_step_acc = 0.1823, eval time = 0.1924s
# Step 2100, Data test loss = -439.9178, imp_weight = -439.9178, opt_loss = 163.5695, reinforce_loss = 603.4873, rec_loss = -439.9178, num_step = 1.5625, num_step_acc = 0.2656, eval time = 0.01952s
#
# Step 2200, Data train loss = -506.4790, imp_weight = -506.4790, opt_loss = 145.8249, reinforce_loss = 652.3039, rec_loss = -506.4790, num_step = 1.7448, num_step_acc = 0.1962, eval time = 0.1837s
# Step 2200, Data test loss = -528.3838, imp_weight = -528.3838, opt_loss = 158.8640, reinforce_loss = 687.2477, rec_loss = -528.3838, num_step = 1.8594, num_step_acc = 0.2812, eval time = 0.01929s
#
# Step 2300, Data train loss = -489.9593, imp_weight = -489.9593, opt_loss = 158.1847, reinforce_loss = 648.1440, rec_loss = -489.9593, num_step = 1.6562, num_step_acc = 0.2135, eval time = 0.1935s
# Step 2300, Data test loss = -388.6034, imp_weight = -388.6034, opt_loss = 121.6649, reinforce_loss = 510.2683, rec_loss = -388.6034, num_step = 1.3750, num_step_acc = 0.1719, eval time = 0.02051s
#
# Step 2400, Data train loss = -477.6754, imp_weight = -477.6754, opt_loss = 145.5300, reinforce_loss = 623.2054, rec_loss = -477.6754, num_step = 1.5972, num_step_acc = 0.2049, eval time = 0.1768s
# Step 2400, Data test loss = -446.9147, imp_weight = -446.9147, opt_loss = 154.3929, reinforce_loss = 601.3076, rec_loss = -446.9147, num_step = 1.6094, num_step_acc = 0.1406, eval time = 0.01921s
#
# Step 2500, Data train loss = -515.4112, imp_weight = -515.4112, opt_loss = 158.9801, reinforce_loss = 674.3913, rec_loss = -515.4112, num_step = 1.7257, num_step_acc = 0.2153, eval time = 0.1807s
# Step 2500, Data test loss = -495.9362, imp_weight = -495.9362, opt_loss = 134.0772, reinforce_loss = 630.0134, rec_loss = -495.9362, num_step = 1.8281, num_step_acc = 0.2344, eval time = 0.02175s
#
# Step 2600, Data train loss = -484.7468, imp_weight = -484.7468, opt_loss = 140.3470, reinforce_loss = 625.0938, rec_loss = -484.7468, num_step = 1.6806, num_step_acc = 0.1823, eval time = 0.2051s
# Step 2600, Data test loss = -414.1449, imp_weight = -414.1449, opt_loss = 141.4342, reinforce_loss = 555.5791, rec_loss = -414.1449, num_step = 1.5312, num_step_acc = 0.1875, eval time = 0.02055s
#
# Step 2700, Data train loss = -493.7129, imp_weight = -493.7129, opt_loss = 159.6190, reinforce_loss = 653.3320, rec_loss = -493.7129, num_step = 1.6736, num_step_acc = 0.2205, eval time = 0.1829s
# Step 2700, Data test loss = -481.1557, imp_weight = -481.1557, opt_loss = 137.5992, reinforce_loss = 618.7549, rec_loss = -481.1557, num_step = 1.8125, num_step_acc = 0.1250, eval time = 0.01957s
#
# Step 2800, Data train loss = -518.3292, imp_weight = -518.3292, opt_loss = 157.9213, reinforce_loss = 676.2505, rec_loss = -518.3292, num_step = 1.7639, num_step_acc = 0.1545, eval time = 0.1887s
# Step 2800, Data test loss = -490.8928, imp_weight = -490.8928, opt_loss = 142.3247, reinforce_loss = 633.2175, rec_loss = -490.8928, num_step = 1.8906, num_step_acc = 0.1875, eval time = 0.0196s
#
# Step 2900, Data train loss = -480.0809, imp_weight = -480.0809, opt_loss = 159.9408, reinforce_loss = 640.0217, rec_loss = -480.0809, num_step = 1.6198, num_step_acc = 0.2083, eval time = 0.1845s
# Step 2900, Data test loss = -476.1976, imp_weight = -476.1976, opt_loss = 163.6129, reinforce_loss = 639.8104, rec_loss = -476.1976, num_step = 1.7344, num_step_acc = 0.1875, eval time = 0.02015s
#
# Step 3000, Data train loss = -490.0462, imp_weight = -490.0462, opt_loss = 169.2715, reinforce_loss = 659.3177, rec_loss = -490.0462, num_step = 1.5938, num_step_acc = 0.1858, eval time = 0.1851s
# Step 3000, Data test loss = -440.6653, imp_weight = -440.6653, opt_loss = 163.8478, reinforce_loss = 604.5131, rec_loss = -440.6653, num_step = 1.5625, num_step_acc = 0.2344, eval time = 0.01893s
#
# Step 3100, Data train loss = -507.2682, imp_weight = -507.2682, opt_loss = 162.2667, reinforce_loss = 669.5349, rec_loss = -507.2682, num_step = 1.6649, num_step_acc = 0.1927, eval time = 0.1816s
# Step 3100, Data test loss = -513.2792, imp_weight = -513.2792, opt_loss = 153.8400, reinforce_loss = 667.1192, rec_loss = -513.2792, num_step = 1.9219, num_step_acc = 0.2344, eval time = 0.01944s
#
# Step 3200, Data train loss = -486.5320, imp_weight = -486.5320, opt_loss = 152.6547, reinforce_loss = 639.1867, rec_loss = -486.5320, num_step = 1.6580, num_step_acc = 0.1649, eval time = 0.1884s
# Step 3200, Data test loss = -471.1091, imp_weight = -471.1091, opt_loss = 189.0028, reinforce_loss = 660.1119, rec_loss = -471.1091, num_step = 1.6562, num_step_acc = 0.2500, eval time = 0.01965s
#
# Step 3300, Data train loss = -485.4296, imp_weight = -485.4296, opt_loss = 158.1172, reinforce_loss = 643.5468, rec_loss = -485.4296, num_step = 1.6545, num_step_acc = 0.1962, eval time = 0.1806s
# Step 3300, Data test loss = -481.0141, imp_weight = -481.0141, opt_loss = 140.8182, reinforce_loss = 621.8323, rec_loss = -481.0141, num_step = 1.7031, num_step_acc = 0.2344, eval time = 0.0195s
#
# Step 3400, Data train loss = -523.7570, imp_weight = -523.7570, opt_loss = 161.4458, reinforce_loss = 685.2028, rec_loss = -523.7570, num_step = 1.8177, num_step_acc = 0.1858, eval time = 0.1849s
# Step 3400, Data test loss = -440.4612, imp_weight = -440.4612, opt_loss = 117.7525, reinforce_loss = 558.2137, rec_loss = -440.4612, num_step = 1.6875, num_step_acc = 0.1562, eval time = 0.02069s
#
# Step 3500, Data train loss = -492.2337, imp_weight = -492.2337, opt_loss = 159.1669, reinforce_loss = 651.4006, rec_loss = -492.2337, num_step = 1.6337, num_step_acc = 0.1979, eval time = 0.1915s
# Step 3500, Data test loss = -490.6989, imp_weight = -490.6989, opt_loss = 135.5252, reinforce_loss = 626.2241, rec_loss = -490.6989, num_step = 1.7812, num_step_acc = 0.2188, eval time = 0.02035s
#
# Step 3600, Data train loss = -503.4376, imp_weight = -503.4376, opt_loss = 168.6262, reinforce_loss = 672.0638, rec_loss = -503.4376, num_step = 1.6476, num_step_acc = 0.2118, eval time = 0.1894s
# Step 3600, Data test loss = -456.8031, imp_weight = -456.8031, opt_loss = 121.2617, reinforce_loss = 578.0648, rec_loss = -456.8031, num_step = 1.8125, num_step_acc = 0.1250, eval time = 0.0211s
#
# Step 3700, Data train loss = -509.4923, imp_weight = -509.4923, opt_loss = 178.2890, reinforce_loss = 687.7813, rec_loss = -509.4923, num_step = 1.6198, num_step_acc = 0.2118, eval time = 0.1873s
# Step 3700, Data test loss = -441.4975, imp_weight = -441.4975, opt_loss = 116.6993, reinforce_loss = 558.1968, rec_loss = -441.4975, num_step = 1.5469, num_step_acc = 0.1562, eval time = 0.01987s
#
# Step 3800, Data train loss = -489.6017, imp_weight = -489.6017, opt_loss = 157.9973, reinforce_loss = 647.5990, rec_loss = -489.6017, num_step = 1.6076, num_step_acc = 0.1997, eval time = 0.1794s
# Step 3800, Data test loss = -475.1974, imp_weight = -475.1974, opt_loss = 142.3359, reinforce_loss = 617.5333, rec_loss = -475.1974, num_step = 1.5938, num_step_acc = 0.1562, eval time = 0.01943s
#
# Step 3900, Data train loss = -510.2092, imp_weight = -510.2092, opt_loss = 155.2937, reinforce_loss = 665.5029, rec_loss = -510.2092, num_step = 1.6962, num_step_acc = 0.1927, eval time = 0.187s
# Step 3900, Data test loss = -491.4785, imp_weight = -491.4785, opt_loss = 161.1837, reinforce_loss = 652.6622, rec_loss = -491.4785, num_step = 1.7500, num_step_acc = 0.1406, eval time = 0.02038s
#
# Step 4000, Data train loss = -500.5419, imp_weight = -500.5419, opt_loss = 162.7120, reinforce_loss = 663.2539, rec_loss = -500.5419, num_step = 1.6337, num_step_acc = 0.2240, eval time = 0.1791s
# Step 4000, Data test loss = -408.6886, imp_weight = -408.6886, opt_loss = 131.5692, reinforce_loss = 540.2578, rec_loss = -408.6886, num_step = 1.4688, num_step_acc = 0.1875, eval time = 0.01974s
#
# Step 4100, Data train loss = -485.9246, imp_weight = -485.9246, opt_loss = 150.5705, reinforce_loss = 636.4951, rec_loss = -485.9246, num_step = 1.6927, num_step_acc = 0.1667, eval time = 0.1862s
# Step 4100, Data test loss = -454.0558, imp_weight = -454.0558, opt_loss = 145.7477, reinforce_loss = 599.8035, rec_loss = -454.0558, num_step = 1.5312, num_step_acc = 0.3125, eval time = 0.02106s
# Step 4200, Data train loss = -529.2955, imp_weight = -529.2955, opt_loss = 171.5116, reinforce_loss = 700.8071, rec_loss = -529.2955, num_step = 1.6823, num_step_acc = 0.2135, eval time = 0.1794s
# Step 4200, Data test loss = -444.4440, imp_weight = -444.4440, opt_loss = 124.4225, reinforce_loss = 568.8665, rec_loss = -444.4440, num_step = 1.5312, num_step_acc = 0.2188, eval time = 0.01897s
#
# Step 4300, Data train loss = -497.1604, imp_weight = -497.1604, opt_loss = 155.8989, reinforce_loss = 653.0593, rec_loss = -497.1604, num_step = 1.6163, num_step_acc = 0.2188, eval time = 0.1787s
# Step 4300, Data test loss = -452.6310, imp_weight = -452.6310, opt_loss = 150.1467, reinforce_loss = 602.7777, rec_loss = -452.6310, num_step = 1.5000, num_step_acc = 0.1875, eval time = 0.01958s
#
# Step 4400, Data train loss = -510.2068, imp_weight = -510.2068, opt_loss = 163.8861, reinforce_loss = 674.0929, rec_loss = -510.2068, num_step = 1.7066, num_step_acc = 0.2101, eval time = 0.1831s
# Step 4400, Data test loss = -510.7336, imp_weight = -510.7336, opt_loss = 167.4985, reinforce_loss = 678.2322, rec_loss = -510.7336, num_step = 1.7500, num_step_acc = 0.2656, eval time = 0.02058s
#
# Step 4500, Data train loss = -511.6130, imp_weight = -511.6130, opt_loss = 172.1419, reinforce_loss = 683.7549, rec_loss = -511.6130, num_step = 1.5816, num_step_acc = 0.2049, eval time = 0.1874s
# Step 4500, Data test loss = -457.1936, imp_weight = -457.1936, opt_loss = 160.1813, reinforce_loss = 617.3749, rec_loss = -457.1936, num_step = 1.6250, num_step_acc = 0.2031, eval time = 0.0199s
#
# Step 4600, Data train loss = -498.8758, imp_weight = -498.8758, opt_loss = 162.4177, reinforce_loss = 661.2935, rec_loss = -498.8758, num_step = 1.6354, num_step_acc = 0.2240, eval time = 0.1814s
# Step 4600, Data test loss = -464.5335, imp_weight = -464.5335, opt_loss = 104.6863, reinforce_loss = 569.2198, rec_loss = -464.5335, num_step = 1.7500, num_step_acc = 0.1719, eval time = 0.02057s
#
# Step 4700, Data train loss = -502.3405, imp_weight = -502.3405, opt_loss = 157.4984, reinforce_loss = 659.8389, rec_loss = -502.3405, num_step = 1.5903, num_step_acc = 0.2222, eval time = 0.1849s
# Step 4700, Data test loss = -426.5716, imp_weight = -426.5716, opt_loss = 106.0887, reinforce_loss = 532.6603, rec_loss = -426.5716, num_step = 1.5625, num_step_acc = 0.1250, eval time = 0.01972s
#
# Step 4800, Data train loss = -503.3460, imp_weight = -503.3460, opt_loss = 158.5167, reinforce_loss = 661.8627, rec_loss = -503.3460, num_step = 1.6719, num_step_acc = 0.1858, eval time = 0.2161s
# Step 4800, Data test loss = -491.0758, imp_weight = -491.0758, opt_loss = 172.6079, reinforce_loss = 663.6837, rec_loss = -491.0758, num_step = 1.8906, num_step_acc = 0.1562, eval time = 0.02074s
#
# Step 4900, Data train loss = -510.8313, imp_weight = -510.8313, opt_loss = 170.7553, reinforce_loss = 681.5866, rec_loss = -510.8313, num_step = 1.6840, num_step_acc = 0.2118, eval time = 0.1853s
# Step 4900, Data test loss = -475.0477, imp_weight = -475.0477, opt_loss = 160.8927, reinforce_loss = 635.9404, rec_loss = -475.0477, num_step = 1.7188, num_step_acc = 0.2812, eval time = 0.02033s
#
# Step 5000, Data train loss = -497.8174, imp_weight = -497.8174, opt_loss = 165.2754, reinforce_loss = 663.0928, rec_loss = -497.8174, num_step = 1.6545, num_step_acc = 0.2170, eval time = 0.1822s
# Step 5000, Data test loss = -400.6880, imp_weight = -400.6880, opt_loss = 105.9121, reinforce_loss = 506.6001, rec_loss = -400.6880, num_step = 1.5469, num_step_acc = 0.1562, eval time = 0.02067s
#
# Step 5100, Data train loss = -517.8908, imp_weight = -517.8908, opt_loss = 157.2347, reinforce_loss = 675.1255, rec_loss = -517.8908, num_step = 1.6372, num_step_acc = 0.2118, eval time = 0.1763s
# Step 5100, Data test loss = -403.5056, imp_weight = -403.5056, opt_loss = 138.1807, reinforce_loss = 541.6863, rec_loss = -403.5056, num_step = 1.4688, num_step_acc = 0.1719, eval time = 0.01844s
#
# Step 5200, Data train loss = -505.8641, imp_weight = -505.8641, opt_loss = 159.3787, reinforce_loss = 665.2428, rec_loss = -505.8641, num_step = 1.6562, num_step_acc = 0.2014, eval time = 0.1894s
# Step 5200, Data test loss = -443.2704, imp_weight = -443.2704, opt_loss = 134.9421, reinforce_loss = 578.2125, rec_loss = -443.2704, num_step = 1.6094, num_step_acc = 0.2500, eval time = 0.02055s
#
# Step 5300, Data train loss = -511.5527, imp_weight = -511.5527, opt_loss = 162.7104, reinforce_loss = 674.2631, rec_loss = -511.5527, num_step = 1.6753, num_step_acc = 0.2188, eval time = 0.178s
# Step 5300, Data test loss = -508.9497, imp_weight = -508.9497, opt_loss = 186.8429, reinforce_loss = 695.7927, rec_loss = -508.9497, num_step = 1.8750, num_step_acc = 0.2188, eval time = 0.01893s
#
# Step 5400, Data train loss = -485.0124, imp_weight = -485.0124, opt_loss = 155.5441, reinforce_loss = 640.5565, rec_loss = -485.0124, num_step = 1.6493, num_step_acc = 0.2031, eval time = 0.1817s
# Step 5400, Data test loss = -467.3091, imp_weight = -467.3091, opt_loss = 154.1368, reinforce_loss = 621.4459, rec_loss = -467.3091, num_step = 1.6250, num_step_acc = 0.2500, eval time = 0.01982s
#
# Step 5500, Data train loss = -510.6025, imp_weight = -510.6025, opt_loss = 162.7059, reinforce_loss = 673.3084, rec_loss = -510.6025, num_step = 1.6493, num_step_acc = 0.2083, eval time = 0.2052s
# Step 5500, Data test loss = -427.7942, imp_weight = -427.7942, opt_loss = 128.9419, reinforce_loss = 556.7361, rec_loss = -427.7942, num_step = 1.4688, num_step_acc = 0.2031, eval time = 0.02155s
#
# Step 5600, Data train loss = -501.1107, imp_weight = -501.1107, opt_loss = 165.7719, reinforce_loss = 666.8826, rec_loss = -501.1107, num_step = 1.6788, num_step_acc = 0.2066, eval time = 0.1918s
# Step 5600, Data test loss = -441.7164, imp_weight = -441.7164, opt_loss = 164.2381, reinforce_loss = 605.9545, rec_loss = -441.7164, num_step = 1.5625, num_step_acc = 0.1719, eval time = 0.02077s
#
# Step 5700, Data train loss = -505.1104, imp_weight = -505.1104, opt_loss = 149.1798, reinforce_loss = 654.2902, rec_loss = -505.1104, num_step = 1.6406, num_step_acc = 0.1927, eval time = 0.1887s
# Step 5700, Data test loss = -429.4128, imp_weight = -429.4128, opt_loss = 144.1428, reinforce_loss = 573.5557, rec_loss = -429.4128, num_step = 1.5781, num_step_acc = 0.1875, eval time = 0.02101s
#
# Step 5800, Data train loss = -514.0332, imp_weight = -514.0332, opt_loss = 142.6460, reinforce_loss = 656.6792, rec_loss = -514.0332, num_step = 1.7135, num_step_acc = 0.1823, eval time = 0.1807s
# Step 5800, Data test loss = -456.1134, imp_weight = -456.1134, opt_loss = 144.6042, reinforce_loss = 600.7176, rec_loss = -456.1134, num_step = 1.4531, num_step_acc = 0.2188, eval time = 0.01979s
#
# Step 5900, Data train loss = -481.8444, imp_weight = -481.8444, opt_loss = 160.4776, reinforce_loss = 642.3220, rec_loss = -481.8444, num_step = 1.6806, num_step_acc = 0.1736, eval time = 0.1833s
# Step 5900, Data test loss = -455.9764, imp_weight = -455.9764, opt_loss = 124.5610, reinforce_loss = 580.5375, rec_loss = -455.9764, num_step = 1.6406, num_step_acc = 0.1875, eval time = 0.0201s
#
# Step 6000, Data train loss = -510.1549, imp_weight = -510.1549, opt_loss = 172.0488, reinforce_loss = 682.2038, rec_loss = -510.1549, num_step = 1.6597, num_step_acc = 0.1927, eval time = 0.1885s
# Step 6000, Data test loss = -531.7264, imp_weight = -531.7264, opt_loss = 153.6640, reinforce_loss = 685.3904, rec_loss = -531.7264, num_step = 1.9531, num_step_acc = 0.1719, eval time = 0.02223s
#
# Step 6100, Data train loss = -499.5552, imp_weight = -499.5552, opt_loss = 166.8709, reinforce_loss = 666.4261, rec_loss = -499.5552, num_step = 1.6823, num_step_acc = 0.2031, eval time = 0.1839s
# Step 6100, Data test loss = -456.3420, imp_weight = -456.3420, opt_loss = 129.1281, reinforce_loss = 585.4701, rec_loss = -456.3420, num_step = 1.6719, num_step_acc = 0.2188, eval time = 0.02013s
#
# Step 6200, Data train loss = -515.2754, imp_weight = -515.2754, opt_loss = 167.0081, reinforce_loss = 682.2835, rec_loss = -515.2754, num_step = 1.6927, num_step_acc = 0.2066, eval time = 0.207s
# Step 6200, Data test loss = -465.4575, imp_weight = -465.4575, opt_loss = 170.3494, reinforce_loss = 635.8069, rec_loss = -465.4575, num_step = 1.6094, num_step_acc = 0.1875, eval time = 0.01994s
# Step 6300, Data train loss = -499.5271, imp_weight = -499.5271, opt_loss = 159.7515, reinforce_loss = 659.2786, rec_loss = -499.5271, num_step = 1.6458, num_step_acc = 0.1892, eval time = 0.1806s
# Step 6300, Data test loss = -470.4097, imp_weight = -470.4097, opt_loss = 145.5066, reinforce_loss = 615.9163, rec_loss = -470.4097, num_step = 1.6250, num_step_acc = 0.2188, eval time = 0.01995s
#
# Step 6400, Data train loss = -528.9655, imp_weight = -528.9655, opt_loss = 170.6001, reinforce_loss = 699.5657, rec_loss = -528.9655, num_step = 1.6545, num_step_acc = 0.2135, eval time = 0.182s
# Step 6400, Data test loss = -511.0793, imp_weight = -511.0793, opt_loss = 218.9889, reinforce_loss = 730.0682, rec_loss = -511.0793, num_step = 1.5469, num_step_acc = 0.2969, eval time = 0.01881s
#
# Step 6500, Data train loss = -502.4463, imp_weight = -502.4463, opt_loss = 156.0632, reinforce_loss = 658.5094, rec_loss = -502.4463, num_step = 1.6267, num_step_acc = 0.1997, eval time = 0.1846s
# Step 6500, Data test loss = -465.3531, imp_weight = -465.3531, opt_loss = 128.5244, reinforce_loss = 593.8774, rec_loss = -465.3531, num_step = 1.7812, num_step_acc = 0.1250, eval time = 0.0229s
#
# Step 6600, Data train loss = -493.2301, imp_weight = -493.2301, opt_loss = 154.2320, reinforce_loss = 647.4622, rec_loss = -493.2301, num_step = 1.5938, num_step_acc = 0.2049, eval time = 0.187s
# Step 6600, Data test loss = -490.6888, imp_weight = -490.6888, opt_loss = 189.6528, reinforce_loss = 680.3417, rec_loss = -490.6888, num_step = 1.6094, num_step_acc = 0.1875, eval time = 0.01992s
#
# Step 6700, Data train loss = -503.9907, imp_weight = -503.9907, opt_loss = 155.6974, reinforce_loss = 659.6880, rec_loss = -503.9907, num_step = 1.6476, num_step_acc = 0.2118, eval time = 0.1895s
# Step 6700, Data test loss = -506.9258, imp_weight = -506.9258, opt_loss = 144.9689, reinforce_loss = 651.8948, rec_loss = -506.9258, num_step = 1.8125, num_step_acc = 0.1406, eval time = 0.02175s
#
# Step 6800, Data train loss = -482.7808, imp_weight = -482.7808, opt_loss = 152.3629, reinforce_loss = 635.1437, rec_loss = -482.7808, num_step = 1.6111, num_step_acc = 0.2014, eval time = 0.1891s
# Step 6800, Data test loss = -441.4261, imp_weight = -441.4261, opt_loss = 153.3274, reinforce_loss = 594.7535, rec_loss = -441.4261, num_step = 1.4844, num_step_acc = 0.1406, eval time = 0.01924s
#
# Step 6900, Data train loss = -510.9605, imp_weight = -510.9605, opt_loss = 158.5291, reinforce_loss = 669.4896, rec_loss = -510.9605, num_step = 1.6806, num_step_acc = 0.1875, eval time = 0.178s
# Step 6900, Data test loss = -497.1833, imp_weight = -497.1833, opt_loss = 165.0208, reinforce_loss = 662.2040, rec_loss = -497.1833, num_step = 1.8281, num_step_acc = 0.1875, eval time = 0.01928s
#
# Step 7000, Data train loss = -508.0530, imp_weight = -508.0530, opt_loss = 150.0820, reinforce_loss = 658.1350, rec_loss = -508.0530, num_step = 1.6233, num_step_acc = 0.2118, eval time = 0.1803s
# Step 7000, Data test loss = -461.9160, imp_weight = -461.9160, opt_loss = 186.6188, reinforce_loss = 648.5348, rec_loss = -461.9160, num_step = 1.4688, num_step_acc = 0.2188, eval time = 0.01906s
#
# Step 7100, Data train loss = -506.5869, imp_weight = -506.5869, opt_loss = 169.2289, reinforce_loss = 675.8158, rec_loss = -506.5869, num_step = 1.6493, num_step_acc = 0.1719, eval time = 0.193s
# Step 7100, Data test loss = -479.4651, imp_weight = -479.4651, opt_loss = 115.0917, reinforce_loss = 594.5568, rec_loss = -479.4651, num_step = 1.7969, num_step_acc = 0.1250, eval time = 0.02192s
#
# Step 7200, Data train loss = -509.8506, imp_weight = -509.8506, opt_loss = 177.7917, reinforce_loss = 687.6423, rec_loss = -509.8506, num_step = 1.5990, num_step_acc = 0.2170, eval time = 0.1799s
# Step 7200, Data test loss = -469.9141, imp_weight = -469.9141, opt_loss = 143.0530, reinforce_loss = 612.9671, rec_loss = -469.9141, num_step = 1.6094, num_step_acc = 0.2500, eval time = 0.01862s
#
# Step 7300, Data train loss = -516.0991, imp_weight = -516.0991, opt_loss = 175.0667, reinforce_loss = 691.1658, rec_loss = -516.0991, num_step = 1.6927, num_step_acc = 0.1875, eval time = 0.1941s
# Step 7300, Data test loss = -413.5389, imp_weight = -413.5389, opt_loss = 137.5683, reinforce_loss = 551.1072, rec_loss = -413.5389, num_step = 1.4375, num_step_acc = 0.2812, eval time = 0.02114s
#
# Step 7400, Data train loss = -514.9921, imp_weight = -514.9921, opt_loss = 166.6445, reinforce_loss = 681.6366, rec_loss = -514.9921, num_step = 1.6580, num_step_acc = 0.1927, eval time = 0.1713s
# Step 7400, Data test loss = -487.1459, imp_weight = -487.1459, opt_loss = 149.7667, reinforce_loss = 636.9126, rec_loss = -487.1459, num_step = 1.7500, num_step_acc = 0.1562, eval time = 0.01897s
#
# Step 7500, Data train loss = -534.1521, imp_weight = -534.1521, opt_loss = 157.5021, reinforce_loss = 691.6542, rec_loss = -534.1521, num_step = 1.7969, num_step_acc = 0.2066, eval time = 0.1791s
# Step 7500, Data test loss = -462.4858, imp_weight = -462.4858, opt_loss = 164.7346, reinforce_loss = 627.2203, rec_loss = -462.4858, num_step = 1.5781, num_step_acc = 0.2500, eval time = 0.01834s
#
# Step 7600, Data train loss = -506.4177, imp_weight = -506.4177, opt_loss = 161.2642, reinforce_loss = 667.6819, rec_loss = -506.4177, num_step = 1.6059, num_step_acc = 0.1962, eval time = 0.1926s
# Step 7600, Data test loss = -444.7030, imp_weight = -444.7030, opt_loss = 137.5551, reinforce_loss = 582.2581, rec_loss = -444.7030, num_step = 1.6250, num_step_acc = 0.1875, eval time = 0.02432s
#
# Step 7700, Data train loss = -516.0117, imp_weight = -516.0117, opt_loss = 177.2264, reinforce_loss = 693.2382, rec_loss = -516.0117, num_step = 1.6215, num_step_acc = 0.2188, eval time = 0.1904s
# Step 7700, Data test loss = -446.3881, imp_weight = -446.3881, opt_loss = 178.5800, reinforce_loss = 624.9681, rec_loss = -446.3881, num_step = 1.3906, num_step_acc = 0.2344, eval time = 0.02218s
#
# Step 7800, Data train loss = -502.7886, imp_weight = -502.7886, opt_loss = 151.9271, reinforce_loss = 654.7156, rec_loss = -502.7886, num_step = 1.7240, num_step_acc = 0.1632, eval time = 0.1876s
# Step 7800, Data test loss = -514.1607, imp_weight = -514.1607, opt_loss = 194.2730, reinforce_loss = 708.4337, rec_loss = -514.1607, num_step = 1.8438, num_step_acc = 0.2031, eval time = 0.0197s
#
# Step 7900, Data train loss = -498.7945, imp_weight = -498.7945, opt_loss = 153.6052, reinforce_loss = 652.3997, rec_loss = -498.7945, num_step = 1.6910, num_step_acc = 0.1997, eval time = 0.1793s
# Step 7900, Data test loss = -417.1134, imp_weight = -417.1134, opt_loss = 120.4619, reinforce_loss = 537.5753, rec_loss = -417.1134, num_step = 1.6250, num_step_acc = 0.1406, eval time = 0.01842s
#
# Step 8000, Data train loss = -524.1217, imp_weight = -524.1217, opt_loss = 174.7444, reinforce_loss = 698.8660, rec_loss = -524.1217, num_step = 1.6701, num_step_acc = 0.2170, eval time = 0.1945s
# Step 8000, Data test loss = -406.4563, imp_weight = -406.4563, opt_loss = 126.4895, reinforce_loss = 532.9458, rec_loss = -406.4563, num_step = 1.5000, num_step_acc = 0.2031, eval time = 0.01972s
#
# Step 8100, Data train loss = -522.4322, imp_weight = -522.4322, opt_loss = 167.0675, reinforce_loss = 689.4997, rec_loss = -522.4322, num_step = 1.6806, num_step_acc = 0.1684, eval time = 0.2173s
# Step 8100, Data test loss = -475.0700, imp_weight = -475.0700, opt_loss = 185.9411, reinforce_loss = 661.0111, rec_loss = -475.0700, num_step = 1.6250, num_step_acc = 0.2500, eval time = 0.02315s
#
# Step 8200, Data train loss = -521.1092, imp_weight = -521.1092, opt_loss = 173.8801, reinforce_loss = 694.9892, rec_loss = -521.1092, num_step = 1.6910, num_step_acc = 0.1997, eval time = 0.1825s
# Step 8200, Data test loss = -491.7811, imp_weight = -491.7811, opt_loss = 179.0585, reinforce_loss = 670.8397, rec_loss = -491.7811, num_step = 1.7344, num_step_acc = 0.1562, eval time = 0.01977s
#
# Step 8300, Data train loss = -500.7788, imp_weight = -500.7788, opt_loss = 150.6287, reinforce_loss = 651.4075, rec_loss = -500.7788, num_step = 1.6267, num_step_acc = 0.1944, eval time = 0.177s
# Step 8300, Data test loss = -524.9537, imp_weight = -524.9537, opt_loss = 201.4141, reinforce_loss = 726.3679, rec_loss = -524.9537, num_step = 1.7969, num_step_acc = 0.2188, eval time = 0.01857s
# Step 8400, Data train loss = -508.5145, imp_weight = -508.5145, opt_loss = 167.4895, reinforce_loss = 676.0039, rec_loss = -508.5145, num_step = 1.6215, num_step_acc = 0.1892, eval time = 0.174s
# Step 8400, Data test loss = -456.2158, imp_weight = -456.2158, opt_loss = 150.4776, reinforce_loss = 606.6934, rec_loss = -456.2158, num_step = 1.6250, num_step_acc = 0.1250, eval time = 0.01928s
#
# Step 8500, Data train loss = -514.5843, imp_weight = -514.5843, opt_loss = 160.0290, reinforce_loss = 674.6133, rec_loss = -514.5843, num_step = 1.6910, num_step_acc = 0.1806, eval time = 0.1772s
# Step 8500, Data test loss = -494.5698, imp_weight = -494.5698, opt_loss = 191.1527, reinforce_loss = 685.7225, rec_loss = -494.5698, num_step = 1.6094, num_step_acc = 0.2656, eval time = 0.01968s
#
# Step 8600, Data train loss = -497.1361, imp_weight = -497.1361, opt_loss = 156.7696, reinforce_loss = 653.9057, rec_loss = -497.1361, num_step = 1.5799, num_step_acc = 0.2031, eval time = 0.2323s
# Step 8600, Data test loss = -406.6876, imp_weight = -406.6876, opt_loss = 116.2256, reinforce_loss = 522.9133, rec_loss = -406.6876, num_step = 1.4844, num_step_acc = 0.2031, eval time = 0.02574s
#
# Step 8700, Data train loss = -501.9016, imp_weight = -501.9016, opt_loss = 158.9065, reinforce_loss = 660.8081, rec_loss = -501.9016, num_step = 1.6580, num_step_acc = 0.1944, eval time = 0.1854s
# Step 8700, Data test loss = -513.4739, imp_weight = -513.4739, opt_loss = 185.8926, reinforce_loss = 699.3665, rec_loss = -513.4739, num_step = 1.5312, num_step_acc = 0.2969, eval time = 0.01955s
#
# Step 8800, Data train loss = -484.2133, imp_weight = -484.2133, opt_loss = 154.3186, reinforce_loss = 638.5318, rec_loss = -484.2133, num_step = 1.6545, num_step_acc = 0.1806, eval time = 0.1909s
# Step 8800, Data test loss = -433.7910, imp_weight = -433.7910, opt_loss = 160.3927, reinforce_loss = 594.1837, rec_loss = -433.7910, num_step = 1.3594, num_step_acc = 0.2344, eval time = 0.01986s
#
# Step 8900, Data train loss = -510.0973, imp_weight = -510.0973, opt_loss = 166.0814, reinforce_loss = 676.1787, rec_loss = -510.0973, num_step = 1.5938, num_step_acc = 0.2014, eval time = 0.186s
# Step 8900, Data test loss = -514.9288, imp_weight = -514.9288, opt_loss = 160.3441, reinforce_loss = 675.2728, rec_loss = -514.9288, num_step = 1.8281, num_step_acc = 0.1562, eval time = 0.0195s
#
# Step 9000, Data train loss = -516.8547, imp_weight = -516.8547, opt_loss = 159.2371, reinforce_loss = 676.0918, rec_loss = -516.8547, num_step = 1.6788, num_step_acc = 0.2170, eval time = 0.1869s
# Step 9000, Data test loss = -475.5326, imp_weight = -475.5326, opt_loss = 153.6265, reinforce_loss = 629.1591, rec_loss = -475.5326, num_step = 1.7344, num_step_acc = 0.1719, eval time = 0.01955s
#
# Step 9100, Data train loss = -527.0467, imp_weight = -527.0467, opt_loss = 192.5479, reinforce_loss = 719.5947, rec_loss = -527.0467, num_step = 1.6181, num_step_acc = 0.2170, eval time = 0.1965s
# Step 9100, Data test loss = -471.4746, imp_weight = -471.4746, opt_loss = 151.3387, reinforce_loss = 622.8134, rec_loss = -471.4746, num_step = 1.5312, num_step_acc = 0.2812, eval time = 0.02077s
#
# Step 9200, Data train loss = -523.8940, imp_weight = -523.8940, opt_loss = 154.9470, reinforce_loss = 678.8410, rec_loss = -523.8940, num_step = 1.7274, num_step_acc = 0.2049, eval time = 0.185s
# Step 9200, Data test loss = -534.3414, imp_weight = -534.3414, opt_loss = 122.5311, reinforce_loss = 656.8726, rec_loss = -534.3414, num_step = 1.8281, num_step_acc = 0.2344, eval time = 0.01978s
#
# Step 9300, Data train loss = -525.0114, imp_weight = -525.0114, opt_loss = 160.7432, reinforce_loss = 685.7547, rec_loss = -525.0114, num_step = 1.6493, num_step_acc = 0.2153, eval time = 0.1851s
# Step 9300, Data test loss = -470.8288, imp_weight = -470.8288, opt_loss = 157.6022, reinforce_loss = 628.4310, rec_loss = -470.8288, num_step = 1.6406, num_step_acc = 0.2500, eval time = 0.01902s
#
# Step 9400, Data train loss = -515.6291, imp_weight = -515.6291, opt_loss = 156.3934, reinforce_loss = 672.0225, rec_loss = -515.6291, num_step = 1.7066, num_step_acc = 0.2049, eval time = 0.1827s
# Step 9400, Data test loss = -462.5505, imp_weight = -462.5505, opt_loss = 155.2662, reinforce_loss = 617.8167, rec_loss = -462.5505, num_step = 1.5781, num_step_acc = 0.2344, eval time = 0.0193s
#
# Step 9500, Data train loss = -521.5024, imp_weight = -521.5024, opt_loss = 162.5650, reinforce_loss = 684.0674, rec_loss = -521.5024, num_step = 1.6788, num_step_acc = 0.2205, eval time = 0.1905s
# Step 9500, Data test loss = -390.3380, imp_weight = -390.3380, opt_loss = 107.3649, reinforce_loss = 497.7029, rec_loss = -390.3380, num_step = 1.5156, num_step_acc = 0.1875, eval time = 0.02019s
#
# Step 9600, Data train loss = -495.1172, imp_weight = -495.1172, opt_loss = 152.0262, reinforce_loss = 647.1434, rec_loss = -495.1172, num_step = 1.6997, num_step_acc = 0.2135, eval time = 0.1929s
# Step 9600, Data test loss = -500.2372, imp_weight = -500.2372, opt_loss = 164.9974, reinforce_loss = 665.2346, rec_loss = -500.2372, num_step = 1.6250, num_step_acc = 0.2969, eval time = 0.02092s
#
# Step 9700, Data train loss = -500.8175, imp_weight = -500.8175, opt_loss = 146.7087, reinforce_loss = 647.5263, rec_loss = -500.8175, num_step = 1.7743, num_step_acc = 0.1753, eval time = 0.1848s
# Step 9700, Data test loss = -487.3063, imp_weight = -487.3063, opt_loss = 149.3573, reinforce_loss = 636.6636, rec_loss = -487.3063, num_step = 1.8125, num_step_acc = 0.1875, eval time = 0.01952s
#
# Step 9800, Data train loss = -537.2497, imp_weight = -537.2497, opt_loss = 172.1399, reinforce_loss = 709.3895, rec_loss = -537.2497, num_step = 1.6823, num_step_acc = 0.2049, eval time = 0.1863s
# Step 9800, Data test loss = -468.7286, imp_weight = -468.7286, opt_loss = 146.8397, reinforce_loss = 615.5684, rec_loss = -468.7286, num_step = 1.7031, num_step_acc = 0.2188, eval time = 0.01919s
#
# Step 9900, Data train loss = -507.0130, imp_weight = -507.0130, opt_loss = 176.2386, reinforce_loss = 683.2515, rec_loss = -507.0130, num_step = 1.5660, num_step_acc = 0.2153, eval time = 0.1835s
# Step 9900, Data test loss = -505.3324, imp_weight = -505.3324, opt_loss = 184.4681, reinforce_loss = 689.8005, rec_loss = -505.3324, num_step = 1.6719, num_step_acc = 0.1562, eval time = 0.01959s
#
# Step 10000, Data train loss = -510.2390, imp_weight = -510.2390, opt_loss = 164.4038, reinforce_loss = 674.6429, rec_loss = -510.2390, num_step = 1.6892, num_step_acc = 0.1910, eval time = 0.1839s
# Step 10000, Data test loss = -525.9117, imp_weight = -525.9117, opt_loss = 141.6863, reinforce_loss = 667.5980, rec_loss = -525.9117, num_step = 1.8906, num_step_acc = 0.1250, eval time = 0.01964s
#
# Step 10100, Data train loss = -499.0955, imp_weight = -499.0955, opt_loss = 154.9612, reinforce_loss = 654.0567, rec_loss = -499.0955, num_step = 1.6649, num_step_acc = 0.1840, eval time = 0.1737s
# Step 10100, Data test loss = -451.8895, imp_weight = -451.8895, opt_loss = 111.5350, reinforce_loss = 563.4245, rec_loss = -451.8895, num_step = 1.6875, num_step_acc = 0.1562, eval time = 0.01766s
#
# Step 10200, Data train loss = -533.3234, imp_weight = -533.3234, opt_loss = 160.3538, reinforce_loss = 693.6773, rec_loss = -533.3234, num_step = 1.4045, num_step_acc = 0.3108, eval time = 0.1909s
# Step 10200, Data test loss = -473.1171, imp_weight = -473.1171, opt_loss = 129.2622, reinforce_loss = 602.3793, rec_loss = -473.1171, num_step = 1.2812, num_step_acc = 0.3281, eval time = 0.01996s
#
# Step 10300, Data train loss = -516.7187, imp_weight = -516.7187, opt_loss = 145.0179, reinforce_loss = 661.7366, rec_loss = -516.7187, num_step = 1.4601, num_step_acc = 0.2847, eval time = 0.1788s
# Step 10300, Data test loss = -488.9934, imp_weight = -488.9934, opt_loss = 137.7415, reinforce_loss = 626.7349, rec_loss = -488.9934, num_step = 1.3906, num_step_acc = 0.2812, eval time = 0.01794s
#
# Step 10400, Data train loss = -508.7402, imp_weight = -508.7402, opt_loss = 143.5083, reinforce_loss = 652.2485, rec_loss = -508.7402, num_step = 1.2986, num_step_acc = 0.3056, eval time = 0.1869s
# Step 10400, Data test loss = -451.9947, imp_weight = -451.9947, opt_loss = 126.1381, reinforce_loss = 578.1328, rec_loss = -451.9947, num_step = 1.5156, num_step_acc = 0.2344, eval time = 0.01889s
# Step 10500, Data train loss = -536.5315, imp_weight = -536.5315, opt_loss = 164.1647, reinforce_loss = 700.6962, rec_loss = -536.5315, num_step = 1.4722, num_step_acc = 0.2639, eval time = 0.194s
# Step 10500, Data test loss = -480.3174, imp_weight = -480.3174, opt_loss = 138.6963, reinforce_loss = 619.0137, rec_loss = -480.3174, num_step = 1.4531, num_step_acc = 0.2500, eval time = 0.02213s
#
# Step 10600, Data train loss = -509.3467, imp_weight = -509.3467, opt_loss = 144.2442, reinforce_loss = 653.5909, rec_loss = -509.3467, num_step = 1.3194, num_step_acc = 0.3056, eval time = 0.1857s
# Step 10600, Data test loss = -502.2973, imp_weight = -502.2973, opt_loss = 173.1334, reinforce_loss = 675.4307, rec_loss = -502.2973, num_step = 1.6094, num_step_acc = 0.2656, eval time = 0.01921s
#
# Step 10700, Data train loss = -509.9578, imp_weight = -509.9578, opt_loss = 147.2362, reinforce_loss = 657.1939, rec_loss = -509.9578, num_step = 1.3906, num_step_acc = 0.2378, eval time = 0.1698s
# Step 10700, Data test loss = -485.5251, imp_weight = -485.5251, opt_loss = 140.1516, reinforce_loss = 625.6766, rec_loss = -485.5251, num_step = 1.3906, num_step_acc = 0.2656, eval time = 0.02042s
#
# Step 10800, Data train loss = -496.7807, imp_weight = -496.7807, opt_loss = 135.7937, reinforce_loss = 632.5744, rec_loss = -496.7807, num_step = 1.3698, num_step_acc = 0.2708, eval time = 0.1797s
# Step 10800, Data test loss = -390.7294, imp_weight = -390.7294, opt_loss = 141.0762, reinforce_loss = 531.8055, rec_loss = -390.7294, num_step = 1.2031, num_step_acc = 0.2031, eval time = 0.01969s
#
# Step 10900, Data train loss = -507.6555, imp_weight = -507.6555, opt_loss = 163.0935, reinforce_loss = 670.7490, rec_loss = -507.6555, num_step = 1.5816, num_step_acc = 0.1979, eval time = 0.18s
# Step 10900, Data test loss = -432.9749, imp_weight = -432.9749, opt_loss = 137.1746, reinforce_loss = 570.1495, rec_loss = -432.9749, num_step = 1.2656, num_step_acc = 0.2344, eval time = 0.01905s
#
# Step 11000, Data train loss = -520.8600, imp_weight = -520.8600, opt_loss = 184.6363, reinforce_loss = 705.4963, rec_loss = -520.8600, num_step = 1.5677, num_step_acc = 0.2222, eval time = 0.1866s
# Step 11000, Data test loss = -439.6118, imp_weight = -439.6118, opt_loss = 133.0849, reinforce_loss = 572.6968, rec_loss = -439.6118, num_step = 1.5156, num_step_acc = 0.1875, eval time = 0.01995s
#
# Step 11100, Data train loss = -513.0170, imp_weight = -513.0170, opt_loss = 158.2145, reinforce_loss = 671.2315, rec_loss = -513.0170, num_step = 1.5139, num_step_acc = 0.2031, eval time = 0.1954s
# Step 11100, Data test loss = -457.5189, imp_weight = -457.5189, opt_loss = 135.3602, reinforce_loss = 592.8792, rec_loss = -457.5189, num_step = 1.5781, num_step_acc = 0.1406, eval time = 0.0213s
#
# Step 11200, Data train loss = -514.1738, imp_weight = -514.1738, opt_loss = 174.6756, reinforce_loss = 688.8494, rec_loss = -514.1738, num_step = 1.4358, num_step_acc = 0.2257, eval time = 0.184s
# Step 11200, Data test loss = -484.3301, imp_weight = -484.3301, opt_loss = 163.1686, reinforce_loss = 647.4987, rec_loss = -484.3301, num_step = 1.5469, num_step_acc = 0.1875, eval time = 0.0198s
#
# Step 11300, Data train loss = -532.9180, imp_weight = -532.9180, opt_loss = 171.3907, reinforce_loss = 704.3087, rec_loss = -532.9180, num_step = 1.5434, num_step_acc = 0.2205, eval time = 0.1862s
# Step 11300, Data test loss = -421.3387, imp_weight = -421.3387, opt_loss = 153.6758, reinforce_loss = 575.0145, rec_loss = -421.3387, num_step = 1.1875, num_step_acc = 0.2344, eval time = 0.01948s
#
# Step 11400, Data train loss = -529.2425, imp_weight = -529.2425, opt_loss = 158.2694, reinforce_loss = 687.5119, rec_loss = -529.2425, num_step = 1.5660, num_step_acc = 0.1910, eval time = 0.1898s
# Step 11400, Data test loss = -506.8892, imp_weight = -506.8892, opt_loss = 130.1128, reinforce_loss = 637.0020, rec_loss = -506.8892, num_step = 1.6250, num_step_acc = 0.1719, eval time = 0.01957s
#
# Step 11500, Data train loss = -506.7543, imp_weight = -506.7543, opt_loss = 175.1356, reinforce_loss = 681.8899, rec_loss = -506.7543, num_step = 1.5781, num_step_acc = 0.2205, eval time = 0.1921s
# Step 11500, Data test loss = -441.1259, imp_weight = -441.1259, opt_loss = 153.7620, reinforce_loss = 594.8879, rec_loss = -441.1259, num_step = 1.5000, num_step_acc = 0.2031, eval time = 0.01968s
#
# Step 11600, Data train loss = -492.1544, imp_weight = -492.1544, opt_loss = 162.1012, reinforce_loss = 654.2555, rec_loss = -492.1544, num_step = 1.4201, num_step_acc = 0.2153, eval time = 0.1826s
# Step 11600, Data test loss = -421.1790, imp_weight = -421.1790, opt_loss = 152.8550, reinforce_loss = 574.0341, rec_loss = -421.1790, num_step = 1.6406, num_step_acc = 0.1250, eval time = 0.01879s
#
# Step 11700, Data train loss = -519.0365, imp_weight = -519.0365, opt_loss = 163.2298, reinforce_loss = 682.2663, rec_loss = -519.0365, num_step = 1.4497, num_step_acc = 0.2292, eval time = 0.1925s
# Step 11700, Data test loss = -440.0466, imp_weight = -440.0466, opt_loss = 144.3561, reinforce_loss = 584.4027, rec_loss = -440.0466, num_step = 1.4062, num_step_acc = 0.1719, eval time = 0.01908s
#
# Step 11800, Data train loss = -536.3221, imp_weight = -536.3221, opt_loss = 161.0096, reinforce_loss = 697.3317, rec_loss = -536.3221, num_step = 1.6406, num_step_acc = 0.1823, eval time = 0.1868s
# Step 11800, Data test loss = -472.8534, imp_weight = -472.8534, opt_loss = 176.8507, reinforce_loss = 649.7041, rec_loss = -472.8534, num_step = 1.4531, num_step_acc = 0.2031, eval time = 0.01965s
#
# Step 11900, Data train loss = -508.5404, imp_weight = -508.5404, opt_loss = 167.1410, reinforce_loss = 675.6814, rec_loss = -508.5404, num_step = 1.5747, num_step_acc = 0.2118, eval time = 0.1839s
# Step 11900, Data test loss = -440.7963, imp_weight = -440.7963, opt_loss = 125.5588, reinforce_loss = 566.3550, rec_loss = -440.7963, num_step = 1.5469, num_step_acc = 0.1562, eval time = 0.02018s
#
# Step 12000, Data train loss = -514.5372, imp_weight = -514.5372, opt_loss = 153.3240, reinforce_loss = 667.8612, rec_loss = -514.5372, num_step = 1.7049, num_step_acc = 0.1875, eval time = 0.1863s
# Step 12000, Data test loss = -510.0632, imp_weight = -510.0632, opt_loss = 164.7822, reinforce_loss = 674.8453, rec_loss = -510.0632, num_step = 1.7344, num_step_acc = 0.1875, eval time = 0.01961s
#
# Step 12100, Data train loss = -517.2863, imp_weight = -517.2863, opt_loss = 156.9630, reinforce_loss = 674.2493, rec_loss = -517.2863, num_step = 1.6806, num_step_acc = 0.1875, eval time = 0.1758s
# Step 12100, Data test loss = -470.3787, imp_weight = -470.3787, opt_loss = 143.6373, reinforce_loss = 614.0160, rec_loss = -470.3787, num_step = 1.5469, num_step_acc = 0.2031, eval time = 0.01873s
#
# ...
#
# Step 76700, Data train loss = -544.7009, imp_weight = -544.7009, opt_loss = 171.8570, reinforce_loss = 716.5579, rec_loss = -544.7009, num_step = 1.6684, num_step_acc = 0.2240, eval time = 0.1948s
# Step 76700, Data test loss = -508.2094, imp_weight = -508.2094, opt_loss = 183.0304, reinforce_loss = 691.2397, rec_loss = -508.2094, num_step = 1.6562, num_step_acc = 0.1562, eval time = 0.02284s
#
# Step 76800, Data train loss = -546.9501, imp_weight = -546.9501, opt_loss = 168.3410, reinforce_loss = 715.2911, rec_loss = -546.9501, num_step = 1.6927, num_step_acc = 0.1875, eval time = 0.1932s
# Step 76800, Data test loss = -495.4789, imp_weight = -495.4789, opt_loss = 113.1530, reinforce_loss = 608.6318, rec_loss = -495.4789, num_step = 1.8906, num_step_acc = 0.1250, eval time = 0.01898s
#
# Step 76900, Data train loss = -544.9348, imp_weight = -544.9348, opt_loss = 158.2406, reinforce_loss = 703.1754, rec_loss = -544.9348, num_step = 1.7674, num_step_acc = 0.1927, eval time = 0.1794s
# Step 76900, Data test loss = -493.7866, imp_weight = -493.7866, opt_loss = 157.5714, reinforce_loss = 651.3580, rec_loss = -493.7866, num_step = 1.6562, num_step_acc = 0.2031, eval time = 0.0226s
#
# Step 77000, Data train loss = -529.4742, imp_weight = -529.4742, opt_loss = 178.0656, reinforce_loss = 707.5398, rec_loss = -529.4742, num_step = 1.6441, num_step_acc = 0.2101, eval time = 0.1825s
# Step 77000, Data test loss = -462.9547, imp_weight = -462.9547, opt_loss = 188.3451, reinforce_loss = 651.2998, rec_loss = -462.9547, num_step = 1.2812, num_step_acc = 0.2969, eval time = 0.0199s
#
# Step 77100, Data train loss = -517.4119, imp_weight = -517.4119, opt_loss = 163.8833, reinforce_loss = 681.2951, rec_loss = -517.4119, num_step = 1.6389, num_step_acc = 0.1910, eval time = 0.1754s
# Step 77100, Data test loss = -485.3723, imp_weight = -485.3723, opt_loss = 159.1812, reinforce_loss = 644.5535, rec_loss = -485.3723, num_step = 1.7500, num_step_acc = 0.1250, eval time = 0.01932s
#
# Step 77200, Data train loss = -529.6114, imp_weight = -529.6114, opt_loss = 168.5011, reinforce_loss = 698.1124, rec_loss = -529.6114, num_step = 1.7153, num_step_acc = 0.1562, eval time = 0.1843s
# Step 77200, Data test loss = -506.3221, imp_weight = -506.3221, opt_loss = 171.0083, reinforce_loss = 677.3304, rec_loss = -506.3221, num_step = 1.7812, num_step_acc = 0.1562, eval time = 0.02055s
#
# Step 77300, Data train loss = -514.9830, imp_weight = -514.9830, opt_loss = 176.8439, reinforce_loss = 691.8269, rec_loss = -514.9830, num_step = 1.5712, num_step_acc = 0.1962, eval time = 0.1809s
# Step 77300, Data test loss = -529.8599, imp_weight = -529.8599, opt_loss = 174.2699, reinforce_loss = 704.1298, rec_loss = -529.8599, num_step = 1.6875, num_step_acc = 0.1562, eval time = 0.01877s
#
# Step 77400, Data train loss = -533.3719, imp_weight = -533.3719, opt_loss = 169.7259, reinforce_loss = 703.0978, rec_loss = -533.3719, num_step = 1.6875, num_step_acc = 0.2309, eval time = 0.19s
# Step 77400, Data test loss = -467.7905, imp_weight = -467.7905, opt_loss = 116.3395, reinforce_loss = 584.1300, rec_loss = -467.7905, num_step = 1.5625, num_step_acc = 0.1094, eval time = 0.02008s
#
# Step 77500, Data train loss = -538.8098, imp_weight = -538.8098, opt_loss = 155.1833, reinforce_loss = 693.9931, rec_loss = -538.8098, num_step = 1.7274, num_step_acc = 0.1962, eval time = 0.1847s
# Step 77500, Data test loss = -566.0469, imp_weight = -566.0469, opt_loss = 156.9758, reinforce_loss = 723.0226, rec_loss = -566.0469, num_step = 2.0469, num_step_acc = 0.1875, eval time = 0.02084s
#
# Step 77600, Data train loss = -517.7282, imp_weight = -517.7282, opt_loss = 172.9769, reinforce_loss = 690.7051, rec_loss = -517.7282, num_step = 1.5799, num_step_acc = 0.1667, eval time = 0.1877s
# Step 77600, Data test loss = -515.1362, imp_weight = -515.1362, opt_loss = 177.4759, reinforce_loss = 692.6121, rec_loss = -515.1362, num_step = 1.6719, num_step_acc = 0.2500, eval time = 0.0209s
# Step 77700, Data train loss = -524.4464, imp_weight = -524.4464, opt_loss = 171.0422, reinforce_loss = 695.4885, rec_loss = -524.4464, num_step = 1.5938, num_step_acc = 0.2257, eval time = 0.1968s
# Step 77700, Data test loss = -468.7150, imp_weight = -468.7150, opt_loss = 122.5704, reinforce_loss = 591.2854, rec_loss = -468.7150, num_step = 1.7344, num_step_acc = 0.1094, eval time = 0.02342s
#
# Step 77800, Data train loss = -535.7700, imp_weight = -535.7700, opt_loss = 168.3706, reinforce_loss = 704.1406, rec_loss = -535.7700, num_step = 1.7083, num_step_acc = 0.2257, eval time = 0.1806s
# Step 77800, Data test loss = -471.8835, imp_weight = -471.8835, opt_loss = 119.6674, reinforce_loss = 591.5508, rec_loss = -471.8835, num_step = 1.5781, num_step_acc = 0.1719, eval time = 0.01873s
#
# Step 77900, Data train loss = -531.2885, imp_weight = -531.2885, opt_loss = 168.0867, reinforce_loss = 699.3751, rec_loss = -531.2885, num_step = 1.6458, num_step_acc = 0.1927, eval time = 0.1776s
# Step 77900, Data test loss = -494.8774, imp_weight = -494.8774, opt_loss = 133.6966, reinforce_loss = 628.5740, rec_loss = -494.8774, num_step = 1.5000, num_step_acc = 0.3281, eval time = 0.01879s
#
# Step 78000, Data train loss = -541.6155, imp_weight = -541.6155, opt_loss = 174.6333, reinforce_loss = 716.2488, rec_loss = -541.6155, num_step = 1.6545, num_step_acc = 0.2118, eval time = 0.1889s
# Step 78000, Data test loss = -499.5539, imp_weight = -499.5539, opt_loss = 181.7935, reinforce_loss = 681.3475, rec_loss = -499.5539, num_step = 1.4062, num_step_acc = 0.2656, eval time = 0.01997s
#
# Step 78100, Data train loss = -535.8346, imp_weight = -535.8346, opt_loss = 183.1062, reinforce_loss = 718.9407, rec_loss = -535.8346, num_step = 1.6354, num_step_acc = 0.2465, eval time = 0.1843s
# Step 78100, Data test loss = -471.9310, imp_weight = -471.9310, opt_loss = 112.8395, reinforce_loss = 584.7704, rec_loss = -471.9310, num_step = 1.8594, num_step_acc = 0.1094, eval time = 0.01793s
#
# Step 78200, Data train loss = -537.1662, imp_weight = -537.1662, opt_loss = 177.8930, reinforce_loss = 715.0592, rec_loss = -537.1662, num_step = 1.7083, num_step_acc = 0.1979, eval time = 0.1848s
# Step 78200, Data test loss = -543.0250, imp_weight = -543.0250, opt_loss = 188.2097, reinforce_loss = 731.2347, rec_loss = -543.0250, num_step = 1.8750, num_step_acc = 0.1562, eval time = 0.01869s
#
# Step 78300, Data train loss = -530.8877, imp_weight = -530.8877, opt_loss = 170.4089, reinforce_loss = 701.2966, rec_loss = -530.8877, num_step = 1.6892, num_step_acc = 0.1997, eval time = 0.1832s
# Step 78300, Data test loss = -492.4000, imp_weight = -492.4000, opt_loss = 106.6093, reinforce_loss = 599.0093, rec_loss = -492.4000, num_step = 1.6562, num_step_acc = 0.1094, eval time = 0.01864s
#
# Step 78400, Data train loss = -546.8543, imp_weight = -546.8543, opt_loss = 159.6636, reinforce_loss = 706.5179, rec_loss = -546.8543, num_step = 1.7465, num_step_acc = 0.2222, eval time = 0.2055s
# Step 78400, Data test loss = -486.5867, imp_weight = -486.5867, opt_loss = 123.4886, reinforce_loss = 610.0753, rec_loss = -486.5867, num_step = 1.9062, num_step_acc = 0.1719, eval time = 0.02076s
#
# Step 78500, Data train loss = -535.7207, imp_weight = -535.7207, opt_loss = 169.4669, reinforce_loss = 705.1876, rec_loss = -535.7207, num_step = 1.6476, num_step_acc = 0.1875, eval time = 0.1854s
# Step 78500, Data test loss = -511.3435, imp_weight = -511.3435, opt_loss = 149.6973, reinforce_loss = 661.0408, rec_loss = -511.3435, num_step = 1.7031, num_step_acc = 0.1875, eval time = 0.0184s
#
# Step 78600, Data train loss = -518.5068, imp_weight = -518.5068, opt_loss = 170.5445, reinforce_loss = 689.0513, rec_loss = -518.5068, num_step = 1.5868, num_step_acc = 0.1962, eval time = 0.1884s
# Step 78600, Data test loss = -519.6650, imp_weight = -519.6650, opt_loss = 147.0461, reinforce_loss = 666.7112, rec_loss = -519.6650, num_step = 1.6719, num_step_acc = 0.2188, eval time = 0.02182s
#
# Step 78700, Data train loss = -529.5711, imp_weight = -529.5711, opt_loss = 180.9781, reinforce_loss = 710.5492, rec_loss = -529.5711, num_step = 1.6250, num_step_acc = 0.2170, eval time = 0.2068s
# Step 78700, Data test loss = -573.7200, imp_weight = -573.7200, opt_loss = 188.8044, reinforce_loss = 762.5244, rec_loss = -573.7200, num_step = 2.0156, num_step_acc = 0.1719, eval time = 0.02003s
#
# Step 78800, Data train loss = -553.5013, imp_weight = -553.5013, opt_loss = 165.2727, reinforce_loss = 718.7740, rec_loss = -553.5013, num_step = 1.7344, num_step_acc = 0.1997, eval time = 0.1772s
# Step 78800, Data test loss = -467.1671, imp_weight = -467.1671, opt_loss = 155.4084, reinforce_loss = 622.5754, rec_loss = -467.1671, num_step = 1.4375, num_step_acc = 0.1562, eval time = 0.01868s
#
# Step 78900, Data train loss = -496.7413, imp_weight = -496.7413, opt_loss = 156.1739, reinforce_loss = 652.9152, rec_loss = -496.7413, num_step = 1.5399, num_step_acc = 0.1927, eval time = 0.1862s
# Step 78900, Data test loss = -468.4506, imp_weight = -468.4506, opt_loss = 155.3947, reinforce_loss = 623.8453, rec_loss = -468.4506, num_step = 1.5000, num_step_acc = 0.2812, eval time = 0.01991s
#
# Step 79000, Data train loss = -530.0861, imp_weight = -530.0861, opt_loss = 183.7355, reinforce_loss = 713.8216, rec_loss = -530.0861, num_step = 1.5833, num_step_acc = 0.2083, eval time = 0.1989s
# Step 79000, Data test loss = -488.1752, imp_weight = -488.1752, opt_loss = 122.8805, reinforce_loss = 611.0557, rec_loss = -488.1752, num_step = 1.7031, num_step_acc = 0.1406, eval time = 0.02134s
#
# Step 79100, Data train loss = -541.1188, imp_weight = -541.1188, opt_loss = 167.6647, reinforce_loss = 708.7834, rec_loss = -541.1188, num_step = 1.6632, num_step_acc = 0.2153, eval time = 0.1968s
# Step 79100, Data test loss = -523.1695, imp_weight = -523.1695, opt_loss = 180.2437, reinforce_loss = 703.4132, rec_loss = -523.1695, num_step = 1.6719, num_step_acc = 0.2031, eval time = 0.01978s
#
# Step 79200, Data train loss = -523.5018, imp_weight = -523.5018, opt_loss = 162.6897, reinforce_loss = 686.1916, rec_loss = -523.5018, num_step = 1.7031, num_step_acc = 0.1632, eval time = 0.1955s
# Step 79200, Data test loss = -501.6842, imp_weight = -501.6842, opt_loss = 151.7810, reinforce_loss = 653.4652, rec_loss = -501.6842, num_step = 1.7344, num_step_acc = 0.2031, eval time = 0.01934s
#
# Step 79300, Data train loss = -533.3949, imp_weight = -533.3949, opt_loss = 163.9075, reinforce_loss = 697.3024, rec_loss = -533.3949, num_step = 1.7257, num_step_acc = 0.2066, eval time = 0.1946s
# Step 79300, Data test loss = -458.4058, imp_weight = -458.4058, opt_loss = 116.6808, reinforce_loss = 575.0867, rec_loss = -458.4058, num_step = 1.5156, num_step_acc = 0.0938, eval time = 0.01978s
#
# Step 79400, Data train loss = -521.0547, imp_weight = -521.0547, opt_loss = 175.7151, reinforce_loss = 696.7698, rec_loss = -521.0547, num_step = 1.5781, num_step_acc = 0.2135, eval time = 0.1828s
# Step 79400, Data test loss = -487.5871, imp_weight = -487.5871, opt_loss = 152.7477, reinforce_loss = 640.3348, rec_loss = -487.5871, num_step = 1.7031, num_step_acc = 0.1562, eval time = 0.02301s
#
# Step 79500, Data train loss = -521.6541, imp_weight = -521.6541, opt_loss = 161.6234, reinforce_loss = 683.2775, rec_loss = -521.6541, num_step = 1.6389, num_step_acc = 0.2014, eval time = 0.187s
# Step 79500, Data test loss = -511.5986, imp_weight = -511.5986, opt_loss = 138.7929, reinforce_loss = 650.3915, rec_loss = -511.5986, num_step = 1.7656, num_step_acc = 0.1562, eval time = 0.02025s
#
# Step 79600, Data train loss = -531.9350, imp_weight = -531.9350, opt_loss = 158.7761, reinforce_loss = 690.7111, rec_loss = -531.9350, num_step = 1.6997, num_step_acc = 0.2014, eval time = 0.2131s
# Step 79600, Data test loss = -461.1268, imp_weight = -461.1268, opt_loss = 131.7837, reinforce_loss = 592.9105, rec_loss = -461.1268, num_step = 1.4844, num_step_acc = 0.2188, eval time = 0.02828s
#
# Step 79700, Data train loss = -538.7074, imp_weight = -538.7074, opt_loss = 172.2197, reinforce_loss = 710.9272, rec_loss = -538.7074, num_step = 1.6597, num_step_acc = 0.2135, eval time = 0.1864s
# Step 79700, Data test loss = -503.7888, imp_weight = -503.7888, opt_loss = 155.3574, reinforce_loss = 659.1461, rec_loss = -503.7888, num_step = 1.6875, num_step_acc = 0.1250, eval time = 0.01986s
# Step 79800, Data train loss = -522.0952, imp_weight = -522.0952, opt_loss = 163.6660, reinforce_loss = 685.7613, rec_loss = -522.0952, num_step = 1.6007, num_step_acc = 0.2222, eval time = 0.2287s
# Step 79800, Data test loss = -482.1916, imp_weight = -482.1916, opt_loss = 132.1759, reinforce_loss = 614.3676, rec_loss = -482.1916, num_step = 1.5781, num_step_acc = 0.1250, eval time = 0.0247s
#
# Step 79900, Data train loss = -520.0135, imp_weight = -520.0135, opt_loss = 166.2109, reinforce_loss = 686.2244, rec_loss = -520.0135, num_step = 1.6441, num_step_acc = 0.1979, eval time = 0.2628s
# Step 79900, Data test loss = -509.9578, imp_weight = -509.9578, opt_loss = 146.7956, reinforce_loss = 656.7534, rec_loss = -509.9578, num_step = 1.6875, num_step_acc = 0.2344, eval time = 0.02842s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-7cc01c6fc59d> in <module>()
#      18
#      19     if train_itr % 100 == 0:
# ---> 20         log(train_itr)
#      21
#      22     if train_itr % 5000 == 0:
#
# /Users/adam/code/attend_infer_repeat/attend_infer_repeat/evaluation.pyc in log(train_itr, **kwargs)
#     106
#     107     def log(train_itr, **kwargs):
# --> 108         train_log(train_itr, **kwargs)
#     109         test_log(train_itr, **kwargs)
#     110         print
#
# /Users/adam/code/attend_infer_repeat/attend_infer_repeat/evaluation.pyc in logger(itr, num_batches_to_eval, write)
#     154                 feed_dict = constants_dict
#     155
# --> 156             r = sess.run(expr_dict, feed_dict)
#     157             for k, v in r.iteritems():
#     158                 l[k] += v
#
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/adam/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
gt, imgs = sess.run([x, air.canvas])

# %%
nt = imgs.shape[0]
fig, axes = plt.subplots(2, nt, figsize=(nt*2, 4), sharex=True, sharey=True)
axes = axes.reshape((2, nt))
n = np.random.randint(imgs.shape[1])
for t, ax in enumerate(axes.T):
    ax[0].imshow(imgs[t, n], cmap='gray', vmin=0., vmax=1.)
    ax[1].imshow(gt[t, n], cmap='gray', vmin=0., vmax=1.)
    for a in ax:
        a.grid(False)
